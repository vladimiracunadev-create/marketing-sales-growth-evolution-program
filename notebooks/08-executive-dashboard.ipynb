# %% [markdown]
# # Executive dashboard
# Dataset: `campaigns.csv`. Work from the business question, then define the metric before interpreting results.

# %%
import pandas as pd
c=pd.read_csv('../datasets/campaigns.csv')
customers=pd.read_csv('../datasets/customers.csv')
summary={'ad_spend_clp':int(c.spend_clp.sum()),'attributed_revenue_clp':int(c.revenue_clp.sum()),'roas':float(c.revenue_clp.sum()/c.spend_clp.sum()),'customer_mrr_clp':int(customers.mrr_clp.sum()),'logo_churn_rate':float(customers.churned.mean())}
summary

# %% [markdown]
# ## Interpretation checklist
# - What decision does this output support?
# - Which denominator/window is used?
# - What data quality issue could reverse the conclusion?
# - What guardrail metric is missing?
