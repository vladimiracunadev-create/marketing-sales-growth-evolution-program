# %% [markdown]
# # E-commerce unit economics
# Dataset: `ecommerce_orders.csv`. Work from the business question, then define the metric before interpreting results.

# %%
import pandas as pd
df=pd.read_csv('../datasets/ecommerce_orders.csv')
df['gross_profit']=df.revenue_clp-df.cogs_clp
df.groupby('channel').agg(orders=('order_id','count'), revenue=('revenue_clp','sum'), gross_profit=('gross_profit','sum'), return_rate=('returned','mean'))

# %% [markdown]
# ## Interpretation checklist
# - What decision does this output support?
# - Which denominator/window is used?
# - What data quality issue could reverse the conclusion?
# - What guardrail metric is missing?
